# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from itertools import product
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
torch.cuda.is_available()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu
# /home/lorenzo/Desktop/Magistrale/ML/env_ml/lib/python3.10/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
def preprocess_monk(file_name):
    '''
    load and preprocess data from the monk dataset
    '''

    # load the dataset, split into input (X) and output (y) variables
    df = pd.read_csv(file_name, delimiter=' ', header=None, names=['remove_this_column','target', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'data_number'], index_col=False)
    df.drop(columns='remove_this_column')

    x1 = np.array(df['x1'])
    x2 = np.array(df['x2'])
    x3 = np.array(df['x3'])
    x4 = np.array(df['x4'])
    x5 = np.array(df['x5'])
    x6 = np.array(df['x6'])
    target = np.array(df['target'])

    encoder = OneHotEncoder(sparse_output=False)

    x1_ =x1.reshape(-1, 1)
    # Fit and transform the data to one-hot encoding
    input_one_hot = encoder.fit_transform(x1_)
    inputs = [x2,x3,x4,x5,x6]

    for x in inputs:
        data =x.reshape(-1, 1)
        # Fit and transform the data to one-hot encoding
        one_hot_encoded = encoder.fit_transform(data)

        # Display the result
        #print("Original data:")
        #print(data)

        #print("\nOne-hot encoded data:")
        #print(one_hot_encoded)

        input_one_hot = np.hstack((input_one_hot, one_hot_encoded))

    #print(input_one_hot.shape)
    #print(input_one_hot[0])
    #print(target)
    #target = 2 * target - 1 #to map from {0,1} to {-1,1}

    x = torch.tensor(input_one_hot, dtype=torch.float32).cuda()
    y = torch.tensor(target, dtype=torch.float32).reshape(-1,1).cuda()
    return x, y

# %%
x_train, y_train = preprocess_monk(file_name='monk_data/monks-1.train')
x_test, y_test = preprocess_monk(file_name='monk_data/monks-1.test')

print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x_train, y_train = preprocess_monk(file_name='monk_data/monks-1.train')
#       2 x_test, y_test = preprocess_monk(file_name='monk_data/monks-1.test')
#       4 print(x_train.shape)
#
# Cell In[3], line 44, in preprocess_monk(file_name)
#      37     input_one_hot = np.hstack((input_one_hot, one_hot_encoded))
#      39 #print(input_one_hot.shape)
#      40 #print(input_one_hot[0])
#      41 #print(target)
#      42 #target = 2 * target - 1 #to map from {0,1} to {-1,1}
# ---> 44 x = torch.tensor(input_one_hot, dtype=torch.float32).cuda()
#      45 y = torch.tensor(target, dtype=torch.float32).reshape(-1,1).cuda()
#      46 return x, y
#
# File ~/Desktop/Magistrale/ML/env_ml/lib/python3.10/site-packages/torch/cuda/__init__.py:298, in _lazy_init()
#     296 if "CUDA_MODULE_LOADING" not in os.environ:
#     297     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 298 torch._C._cuda_init()
#     299 # Some of the queued calls may reentrantly call _lazy_init();
#     300 # we need to just return without initializing in that case.
#     301 # However, we must not let any *other* threads in!
#     302 _tls.is_initializing = True
#
# RuntimeError: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero.

# %%
# Define the classifier
class SimpleClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        output = self.sigmoid(x)
        return output

# Set hyperparameters
input_size = 17
output_size = 1

hidden_size = 8
learning_rate = 0.1
momentum = 0.8
bs = 8

num_epochs = 1000 # max number

# Create an instance of the model
model = SimpleClassifier(input_size, hidden_size, output_size)
model.to(device)
# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)

train_dataset = torch.utils.data.TensorDataset(x_train, y_train)
test_dataset = torch.utils.data.TensorDataset(x_test, y_test)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=bs, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=bs, shuffle=False)



# Lists to store training and test losses for plotting
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

prev_loss = float('inf')
patience_counter = 0
patience = 10
for epoch in range(num_epochs):
    total_loss = 0.0
    total_accuracy = 0.0
    # Mini-batch training

    model.train()  # Set the model to training mode
    for inputs, labels in train_dataloader:

        # Zero the gradients
        optimizer.zero_grad()
        # Forward pass
        outputs = model(inputs)
        # Compute the loss
        loss = criterion(outputs, labels)
        # Backward pass
        loss.backward()
        # Update weights
        optimizer.step()

        prev_loss = loss.item()
        # Accumulate the total loss for this epoch
        total_loss += loss.item()

        # Calculate training accuracy
        predicted_labels = torch.round(outputs)
        correct_predictions = (predicted_labels == labels).sum().item()
        total_samples = labels.size(0)
        total_accuracy += correct_predictions / total_samples

    # Print average training loss and accuracy for the epoch
    average_loss = total_loss / len(train_dataloader)
    average_accuracy = total_accuracy / len(train_dataloader)

    print(f'Training - Epoch [{epoch+1}/{num_epochs}], Loss: {average_loss:.4f}, '
          f'Accuracy: {average_accuracy:.4f}')

    train_losses.append(average_loss)
    train_accuracies.append(average_accuracy)



    # Evaluation on the test set
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        total_test_loss = 0.0
        total_test_accuracy = 0.0
        for test_inputs, test_labels in test_dataloader:
            test_outputs = model(test_inputs)
            test_loss = criterion(test_outputs, test_labels)
            total_test_loss += test_loss.item()

            # Calculate test accuracy
            predicted_labels = torch.round(test_outputs)
            correct_predictions = (predicted_labels == test_labels).sum().item()
            total_samples = test_labels.size(0)
            total_test_accuracy += correct_predictions / total_samples

        average_test_loss = total_test_loss / len(test_dataloader)
        average_test_accuracy = total_test_accuracy / len(test_dataloader)

        print(f'Test - Epoch [{epoch+1}/{num_epochs}], Loss: {average_test_loss:.4f},'
               f'Accuracy: {average_test_accuracy:.4f}')

        test_accuracies.append(average_test_accuracy)
        test_losses.append(average_test_loss)

    # Check for convergence
    if abs(prev_loss - average_loss) < 1e-3:
        patience_counter += 1
    else:
        patience_counter = 0

    if patience_counter == patience:
        print(f"Convergence reached. at epoch {epoch+1} Stopping training.")
        break
    #epochs_reached = epoch+2
    prev_loss = average_loss
# Plot the training and test losses
plt.figure(figsize=(12, 4))

# Loss plots
plt.subplot(1, 2, 1)
plt.plot(range(1, epoch + 2), train_losses, label='Training Loss')
plt.plot(range(1, epoch + 2), test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy plots
plt.subplot(1, 2, 2)
plt.plot(range(1, epoch + 2), train_accuracies, label='Training Accuracy')
plt.plot(range(1, epoch + 2), test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Training - Epoch [1/1000], Loss: 0.2537, Accuracy: 0.5078
# Test - Epoch [1/1000], Loss: 0.2497,Accuracy: 0.5278
# Training - Epoch [2/1000], Loss: 0.2422, Accuracy: 0.6172
# Test - Epoch [2/1000], Loss: 0.2458,Accuracy: 0.5995
# Training - Epoch [3/1000], Loss: 0.2301, Accuracy: 0.7500
# Test - Epoch [3/1000], Loss: 0.2382,Accuracy: 0.6389
# Training - Epoch [4/1000], Loss: 0.2213, Accuracy: 0.6797
# Test - Epoch [4/1000], Loss: 0.2313,Accuracy: 0.6528
# Training - Epoch [5/1000], Loss: 0.2007, Accuracy: 0.7500
# Test - Epoch [5/1000], Loss: 0.2216,Accuracy: 0.6944
# Training - Epoch [6/1000], Loss: 0.1867, Accuracy: 0.7969
# Test - Epoch [6/1000], Loss: 0.2099,Accuracy: 0.7083
# Training - Epoch [7/1000], Loss: 0.1706, Accuracy: 0.8125
# Test - Epoch [7/1000], Loss: 0.2036,Accuracy: 0.7292
# Training - Epoch [8/1000], Loss: 0.1587, Accuracy: 0.8125
# Test - Epoch [8/1000], Loss: 0.1932,Accuracy: 0.7431
# Training - Epoch [9/1000], Loss: 0.1455, Accuracy: 0.8359
# Test - Epoch [9/1000], Loss: 0.1996,Accuracy: 0.7130
# Training - Epoch [10/1000], Loss: 0.1470, Accuracy: 0.8516
# Test - Epoch [10/1000], Loss: 0.1832,Accuracy: 0.7569
# Training - Epoch [11/1000], Loss: 0.1411, Accuracy: 0.8047
# Test - Epoch [11/1000], Loss: 0.1770,Accuracy: 0.7616
# Training - Epoch [12/1000], Loss: 0.1309, Accuracy: 0.8594
# Test - Epoch [12/1000], Loss: 0.1741,Accuracy: 0.7731
# Training - Epoch [13/1000], Loss: 0.1291, Accuracy: 0.8750
# Test - Epoch [13/1000], Loss: 0.1649,Accuracy: 0.7986
# Training - Epoch [14/1000], Loss: 0.1210, Accuracy: 0.8672
# Test - Epoch [14/1000], Loss: 0.1661,Accuracy: 0.7870
# Training - Epoch [15/1000], Loss: 0.1276, Accuracy: 0.8828
# Test - Epoch [15/1000], Loss: 0.1546,Accuracy: 0.8194
# Training - Epoch [16/1000], Loss: 0.1142, Accuracy: 0.8672
# Test - Epoch [16/1000], Loss: 0.1483,Accuracy: 0.8264
# Training - Epoch [17/1000], Loss: 0.0997, Accuracy: 0.8906
# Test - Epoch [17/1000], Loss: 0.1360,Accuracy: 0.8449
# Training - Epoch [18/1000], Loss: 0.1006, Accuracy: 0.8984
# Test - Epoch [18/1000], Loss: 0.1263,Accuracy: 0.8472
# Training - Epoch [19/1000], Loss: 0.0802, Accuracy: 0.9141
# Test - Epoch [19/1000], Loss: 0.1136,Accuracy: 0.8565
# Training - Epoch [20/1000], Loss: 0.0697, Accuracy: 0.9453
# Test - Epoch [20/1000], Loss: 0.0979,Accuracy: 0.8727
# Training - Epoch [21/1000], Loss: 0.0536, Accuracy: 0.9766
# Test - Epoch [21/1000], Loss: 0.0841,Accuracy: 0.8958
# Training - Epoch [22/1000], Loss: 0.0488, Accuracy: 0.9688
# Test - Epoch [22/1000], Loss: 0.0767,Accuracy: 0.9144
# Training - Epoch [23/1000], Loss: 0.0357, Accuracy: 0.9922
# Test - Epoch [23/1000], Loss: 0.0619,Accuracy: 0.9421
# Training - Epoch [24/1000], Loss: 0.0286, Accuracy: 1.0000
# Test - Epoch [24/1000], Loss: 0.0540,Accuracy: 0.9491
# Training - Epoch [25/1000], Loss: 0.0236, Accuracy: 1.0000
# Test - Epoch [25/1000], Loss: 0.0460,Accuracy: 0.9606
# Training - Epoch [26/1000], Loss: 0.0188, Accuracy: 1.0000
# Test - Epoch [26/1000], Loss: 0.0473,Accuracy: 0.9583
# Training - Epoch [27/1000], Loss: 0.0166, Accuracy: 1.0000
# Test - Epoch [27/1000], Loss: 0.0367,Accuracy: 0.9676
# Training - Epoch [28/1000], Loss: 0.0136, Accuracy: 1.0000
# Test - Epoch [28/1000], Loss: 0.0331,Accuracy: 0.9722
# Training - Epoch [29/1000], Loss: 0.0116, Accuracy: 1.0000
# Test - Epoch [29/1000], Loss: 0.0291,Accuracy: 0.9792
# Training - Epoch [30/1000], Loss: 0.0098, Accuracy: 1.0000
# Test - Epoch [30/1000], Loss: 0.0254,Accuracy: 0.9815
# Training - Epoch [31/1000], Loss: 0.0081, Accuracy: 1.0000
# Test - Epoch [31/1000], Loss: 0.0228,Accuracy: 0.9861
# Training - Epoch [32/1000], Loss: 0.0073, Accuracy: 1.0000
# Test - Epoch [32/1000], Loss: 0.0216,Accuracy: 0.9838
# Training - Epoch [33/1000], Loss: 0.0065, Accuracy: 1.0000
# Test - Epoch [33/1000], Loss: 0.0204,Accuracy: 0.9838
# Training - Epoch [34/1000], Loss: 0.0059, Accuracy: 1.0000
# Test - Epoch [34/1000], Loss: 0.0193,Accuracy: 0.9838
# Training - Epoch [35/1000], Loss: 0.0053, Accuracy: 1.0000
# Test - Epoch [35/1000], Loss: 0.0170,Accuracy: 0.9907
# Training - Epoch [36/1000], Loss: 0.0048, Accuracy: 1.0000
# Test - Epoch [36/1000], Loss: 0.0158,Accuracy: 0.9907
# Training - Epoch [37/1000], Loss: 0.0044, Accuracy: 1.0000
# Test - Epoch [37/1000], Loss: 0.0154,Accuracy: 0.9907
# Training - Epoch [38/1000], Loss: 0.0040, Accuracy: 1.0000
# Test - Epoch [38/1000], Loss: 0.0142,Accuracy: 0.9954
# Training - Epoch [39/1000], Loss: 0.0038, Accuracy: 1.0000
# Test - Epoch [39/1000], Loss: 0.0135,Accuracy: 0.9954
# Training - Epoch [40/1000], Loss: 0.0035, Accuracy: 1.0000
# Test - Epoch [40/1000], Loss: 0.0129,Accuracy: 0.9954
# Training - Epoch [41/1000], Loss: 0.0033, Accuracy: 1.0000
# Test - Epoch [41/1000], Loss: 0.0119,Accuracy: 0.9954
# Training - Epoch [42/1000], Loss: 0.0031, Accuracy: 1.0000
# Test - Epoch [42/1000], Loss: 0.0113,Accuracy: 0.9954
# Training - Epoch [43/1000], Loss: 0.0028, Accuracy: 1.0000
# Test - Epoch [43/1000], Loss: 0.0107,Accuracy: 0.9954
# Training - Epoch [44/1000], Loss: 0.0026, Accuracy: 1.0000
# Test - Epoch [44/1000], Loss: 0.0103,Accuracy: 0.9954
# Training - Epoch [45/1000], Loss: 0.0025, Accuracy: 1.0000
# Test - Epoch [45/1000], Loss: 0.0099,Accuracy: 0.9954
# Training - Epoch [46/1000], Loss: 0.0025, Accuracy: 1.0000
# Test - Epoch [46/1000], Loss: 0.0095,Accuracy: 0.9954
# Training - Epoch [47/1000], Loss: 0.0023, Accuracy: 1.0000
# Test - Epoch [47/1000], Loss: 0.0092,Accuracy: 0.9977
# Training - Epoch [48/1000], Loss: 0.0022, Accuracy: 1.0000
# Test - Epoch [48/1000], Loss: 0.0086,Accuracy: 0.9977
# Training - Epoch [49/1000], Loss: 0.0020, Accuracy: 1.0000
# Test - Epoch [49/1000], Loss: 0.0086,Accuracy: 0.9977
# Training - Epoch [50/1000], Loss: 0.0019, Accuracy: 1.0000
# Test - Epoch [50/1000], Loss: 0.0082,Accuracy: 0.9977
# Training - Epoch [51/1000], Loss: 0.0019, Accuracy: 1.0000
# Test - Epoch [51/1000], Loss: 0.0078,Accuracy: 0.9977
# Training - Epoch [52/1000], Loss: 0.0018, Accuracy: 1.0000
# Test - Epoch [52/1000], Loss: 0.0076,Accuracy: 0.9977
# Training - Epoch [53/1000], Loss: 0.0017, Accuracy: 1.0000
# Test - Epoch [53/1000], Loss: 0.0075,Accuracy: 0.9977
# Training - Epoch [54/1000], Loss: 0.0017, Accuracy: 1.0000
# Test - Epoch [54/1000], Loss: 0.0072,Accuracy: 0.9977
# Training - Epoch [55/1000], Loss: 0.0016, Accuracy: 1.0000
# Test - Epoch [55/1000], Loss: 0.0070,Accuracy: 0.9977
# Training - Epoch [56/1000], Loss: 0.0015, Accuracy: 1.0000
# Test - Epoch [56/1000], Loss: 0.0068,Accuracy: 1.0000
# Training - Epoch [57/1000], Loss: 0.0015, Accuracy: 1.0000
# Test - Epoch [57/1000], Loss: 0.0066,Accuracy: 1.0000
# Training - Epoch [58/1000], Loss: 0.0014, Accuracy: 1.0000
# Test - Epoch [58/1000], Loss: 0.0063,Accuracy: 1.0000
# Training - Epoch [59/1000], Loss: 0.0014, Accuracy: 1.0000
# Test - Epoch [59/1000], Loss: 0.0061,Accuracy: 1.0000
# Training - Epoch [60/1000], Loss: 0.0014, Accuracy: 1.0000
# Test - Epoch [60/1000], Loss: 0.0060,Accuracy: 1.0000
# Training - Epoch [61/1000], Loss: 0.0013, Accuracy: 1.0000
# Test - Epoch [61/1000], Loss: 0.0058,Accuracy: 1.0000
# Training - Epoch [62/1000], Loss: 0.0013, Accuracy: 1.0000
# Test - Epoch [62/1000], Loss: 0.0056,Accuracy: 1.0000
# Training - Epoch [63/1000], Loss: 0.0012, Accuracy: 1.0000
# Test - Epoch [63/1000], Loss: 0.0054,Accuracy: 1.0000
# Training - Epoch [64/1000], Loss: 0.0012, Accuracy: 1.0000
# Test - Epoch [64/1000], Loss: 0.0053,Accuracy: 1.0000
# Training - Epoch [65/1000], Loss: 0.0012, Accuracy: 1.0000
# Test - Epoch [65/1000], Loss: 0.0051,Accuracy: 1.0000
# Training - Epoch [66/1000], Loss: 0.0011, Accuracy: 1.0000
# Test - Epoch [66/1000], Loss: 0.0051,Accuracy: 1.0000
# Training - Epoch [67/1000], Loss: 0.0011, Accuracy: 1.0000
# Test - Epoch [67/1000], Loss: 0.0050,Accuracy: 1.0000
# Training - Epoch [68/1000], Loss: 0.0010, Accuracy: 1.0000
# Test - Epoch [68/1000], Loss: 0.0048,Accuracy: 1.0000
# Training - Epoch [69/1000], Loss: 0.0010, Accuracy: 1.0000
# Test - Epoch [69/1000], Loss: 0.0049,Accuracy: 1.0000
# Training - Epoch [70/1000], Loss: 0.0010, Accuracy: 1.0000
# Test - Epoch [70/1000], Loss: 0.0047,Accuracy: 1.0000
# Training - Epoch [71/1000], Loss: 0.0009, Accuracy: 1.0000
# Test - Epoch [71/1000], Loss: 0.0046,Accuracy: 1.0000
# Training - Epoch [72/1000], Loss: 0.0009, Accuracy: 1.0000
# Test - Epoch [72/1000], Loss: 0.0045,Accuracy: 1.0000
# Training - Epoch [73/1000], Loss: 0.0009, Accuracy: 1.0000
# Test - Epoch [73/1000], Loss: 0.0044,Accuracy: 1.0000
# Training - Epoch [74/1000], Loss: 0.0009, Accuracy: 1.0000
# Test - Epoch [74/1000], Loss: 0.0043,Accuracy: 1.0000
# Training - Epoch [75/1000], Loss: 0.0008, Accuracy: 1.0000
# Test - Epoch [75/1000], Loss: 0.0043,Accuracy: 1.0000
# Training - Epoch [76/1000], Loss: 0.0008, Accuracy: 1.0000
# Test - Epoch [76/1000], Loss: 0.0042,Accuracy: 1.0000
# Convergence reached. at epoch 76 Stopping training.
